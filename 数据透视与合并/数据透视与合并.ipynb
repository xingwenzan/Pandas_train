# %% [markdown]
# # pandas 进阶修炼
# <br>
# 本习题基于 `pandas` 版本 `1.1.3`，所有内容应当在 `Jupyter Notebook` 中执行以获得最佳效果。
#
#
# 不同版本之间写法可能会有少许不同，如若碰到此情况，你应该学会如何自行检索解决。

# %% [markdown]
# ## 7 - 数据透视与合并
#
#
#
# <br>
#
# **<font color = '#5172F0'><font size=3.5>必读👇👇👇**</font>
#
# 现在让我们继续练习 pandas数据分析另一组常用操作 --> **数据透视与合并**
#
#
# 本节习题将涉及四大函数：
#
# - pivot_table
# - concat
# - merge
# - join
#
# 随着练习的深入，若没有一定的基础知识将很难继续刷题
#
# 官方文档永远是最好的学习手册，在本节之前强烈建议学习[官方文档对应部分](https://pandas.pydata.org/pandas-docs/version/0.20/merging.html#database-style-dataframe-joining-merging)

# %% [markdown]
# ## 数据透视表
#
# ![](http://liuzaoqi.oss-cn-beijing.aliyuncs.com/2021/09/14/16316101294678.jpg?域名/sample.jpg?x-oss-process=style/stylename)

# %% [markdown]
# ### 1 - 加载数据
#
# 读取当前目录下 `"某超市销售数据.csv"` 并设置千分位符号为 `,`

# %%
import pandas as pd
df = pd.read_csv('某超市销售数据.csv',thousands=',')

# %%
df.head()
# Out:
#        订单ID      订单日期 邮寄方式  国家  地区 省/自治区   细分    类别  子类别       制造商  \
# 0  A1000001  2013/1/1   二级  中国  中南    湖南   公司  办公用品  收纳具    Rogers
# 1  A1000001  2013/1/1   二级  中国  中南    湖南   公司    家具   桌子  Barricks
# 2  A1000001  2013/1/1   二级  中国  中南    湖南   公司    技术   电话       诺基亚
# 3  A1000001  2013/1/1   二级  中国  中南    湖南   公司    技术   配件       贝尔金
# 4  A1000003  2013/1/2   二级  中国  华东    福建  消费者  办公用品  收纳具    Rogers
#
#               产品名称  数量   销售额    利润
# 0  Rogers 文件车, 单宽度   5  3305  1322
# 1  Barricks 圆桌, 白色   3  5289  -635
# 2     诺基亚 智能手机, 整包   3  1725    69
# 3      贝尔金 记忆卡, 实惠   3  1607   611
# 4     Rogers 盒, 工业   4   456   128

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9935 entries, 0 to 9934
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   订单ID    9935 non-null   object
#  1   订单日期    9935 non-null   object
#  2   邮寄方式    9935 non-null   object
#  3   国家      9935 non-null   object
#  4   地区      9935 non-null   object
#  5   省/自治区   9935 non-null   object
#  6   细分      9935 non-null   object
#  7   类别      9935 non-null   object
#  8   子类别     9935 non-null   object
#  9   制造商     9935 non-null   object
#  10  产品名称    9935 non-null   object
#  11  数量      9935 non-null   int64
#  12  销售额     9935 non-null   int64
#  13  利润      9935 non-null   int64
# dtypes: int64(3), object(11)
# memory usage: 1.1+ MB

# %% [markdown]
# ### 2 - 数据透视｜默认
#
# 制作各省「平均销售额」的数据透视表

# %%
import numpy as np

# %%
pd.pivot_table(df,values=['销售额'],index=['省/自治区'],aggfunc=[np.mean])
# Out:
#               mean
#                销售额
# 省/自治区
# 上海     1875.712934
# 云南     1863.789030
# 内蒙古    1314.826316
# 北京     1726.857143
# 吉林     1701.563567
# 四川     1157.875536
# 天津     1611.206667
# 宁夏     1651.680000
# 安徽     1477.868251
# 山东     1642.659111
# 山西     1751.359184
# 广东     1592.185340
# 广西     1675.061135
# 新疆     1402.384615
# 江苏     1279.898089
# 江西     1966.477876
# 河北     1780.275248
# 河南     1558.400335
# 浙江     1347.277778
# 海南     1721.982759
# 湖北     1324.808442
# 湖南     1603.702222
# 甘肃     1602.893443
# 福建     1732.044693
# 西藏      201.000000
# 贵州     1425.978723
# 辽宁     1363.381982
# 重庆     1383.082927
# 陕西     1880.606635
# 青海     2978.954545
# 黑龙江    1800.438503

# %%
pd.pivot_table(df,values=['销售额'],index=['省/自治区'])
# Out:
#                销售额
# 省/自治区
# 上海     1875.712934
# 云南     1863.789030
# 内蒙古    1314.826316
# 北京     1726.857143
# 吉林     1701.563567
# 四川     1157.875536
# 天津     1611.206667
# 宁夏     1651.680000
# 安徽     1477.868251
# 山东     1642.659111
# 山西     1751.359184
# 广东     1592.185340
# 广西     1675.061135
# 新疆     1402.384615
# 江苏     1279.898089
# 江西     1966.477876
# 河北     1780.275248
# 河南     1558.400335
# 浙江     1347.277778
# 海南     1721.982759
# 湖北     1324.808442
# 湖南     1603.702222
# 甘肃     1602.893443
# 福建     1732.044693
# 西藏      201.000000
# 贵州     1425.978723
# 辽宁     1363.381982
# 重庆     1383.082927
# 陕西     1880.606635
# 青海     2978.954545
# 黑龙江    1800.438503

# %%
pd.pivot_table(df,values=['销售额'],index=['省/自治区'],aggfunc='mean')
# Out:
#                销售额
# 省/自治区
# 上海     1875.712934
# 云南     1863.789030
# 内蒙古    1314.826316
# 北京     1726.857143
# 吉林     1701.563567
# 四川     1157.875536
# 天津     1611.206667
# 宁夏     1651.680000
# 安徽     1477.868251
# 山东     1642.659111
# 山西     1751.359184
# 广东     1592.185340
# 广西     1675.061135
# 新疆     1402.384615
# 江苏     1279.898089
# 江西     1966.477876
# 河北     1780.275248
# 河南     1558.400335
# 浙江     1347.277778
# 海南     1721.982759
# 湖北     1324.808442
# 湖南     1603.702222
# 甘肃     1602.893443
# 福建     1732.044693
# 西藏      201.000000
# 贵州     1425.978723
# 辽宁     1363.381982
# 重庆     1383.082927
# 陕西     1880.606635
# 青海     2978.954545
# 黑龙江    1800.438503

# %% [markdown]
# ### 3 - 数据透视｜指定方法
#
# 制作各省「销售总额」的数据透视表

# %%
pd.pivot_table(df,values=['销售额'],index=['省/自治区'],aggfunc='sum')
# Out:
#            销售额
# 省/自治区
# 上海      594601
# 云南      441718
# 内蒙古     249817
# 北京      350552
# 吉林      896724
# 四川      269785
# 天津      483362
# 宁夏       41292
# 安徽      684253
# 山东     1884130
# 山西      429083
# 广东     1520537
# 广西      383589
# 新疆       72924
# 江苏      401888
# 江西      222212
# 河北      899039
# 河南      930365
# 浙江      266761
# 海南       99875
# 湖北      408041
# 湖南      721666
# 甘肃      195553
# 福建      620072
# 西藏         201
# 贵州       67021
# 辽宁      756677
# 重庆      283532
# 陕西      396808
# 青海       65537
# 黑龙江    1346728

# %% [markdown]
# ### 4 - 数据透视｜多方法
#
# 制作各省「销售总额」与「平均销售额」的数据透视表

# %%
pd.pivot_table(df,values=['销售额'],index=['省/自治区'],aggfunc=['sum','mean'])
# Out:
#            sum         mean
#            销售额          销售额
# 省/自治区
# 上海      594601  1875.712934
# 云南      441718  1863.789030
# 内蒙古     249817  1314.826316
# 北京      350552  1726.857143
# 吉林      896724  1701.563567
# 四川      269785  1157.875536
# 天津      483362  1611.206667
# 宁夏       41292  1651.680000
# 安徽      684253  1477.868251
# 山东     1884130  1642.659111
# 山西      429083  1751.359184
# 广东     1520537  1592.185340
# 广西      383589  1675.061135
# 新疆       72924  1402.384615
# 江苏      401888  1279.898089
# 江西      222212  1966.477876
# 河北      899039  1780.275248
# 河南      930365  1558.400335
# 浙江      266761  1347.277778
# 海南       99875  1721.982759
# 湖北      408041  1324.808442
# 湖南      721666  1603.702222
# 甘肃      195553  1602.893443
# 福建      620072  1732.044693
# 西藏         201   201.000000
# 贵州       67021  1425.978723
# 辽宁      756677  1363.381982
# 重庆      283532  1383.082927
# 陕西      396808  1880.606635
# 青海       65537  2978.954545
# 黑龙江    1346728  1800.438503

# %% [markdown]
# ### 5 - 数据透视｜多指标
#
# 制作各省市「销售总额」与「利润总额」的数据透视表

# %%
pd.pivot_table(df,values=['销售额','利润'],index=['省/自治区'],aggfunc='sum')
# Out:
#            利润      销售额
# 省/自治区
# 上海      87236   594601
# 云南      83201   441718
# 内蒙古    -20685   249817
# 北京      57883   350552
# 吉林     152504   896724
# 四川     -16615   269785
# 天津      63108   483362
# 宁夏      -1149    41292
# 安徽     133312   684253
# 山东     310042  1884130
# 山西      79913   429083
# 广东     278591  1520537
# 广西      61444   383589
# 新疆      13696    72924
# 江苏      -6500   401888
# 江西      27144   222212
# 河北     153247   899039
# 河南     168714   930365
# 浙江     -17024   266761
# 海南      21298    99875
# 湖北     -22896   408041
# 湖南      92944   721666
# 甘肃     -25298   195553
# 福建     133791   620072
# 西藏          4      201
# 贵州       5408    67021
# 辽宁     -24930   756677
# 重庆      39688   283532
# 陕西      61753   396808
# 青海       4354    65537
# 黑龙江    228262  1346728

# %% [markdown]
# ### 6 - 数据透视｜多索引
#
# 制作「各省市」与「不同类别」产品「销售总额」的数据透视表

# %%
pd.pivot_table(df,values=['销售额'],index=['省/自治区','类别'],aggfunc='sum')
# Out:
#                销售额
# 省/自治区 类别
# 上海    办公用品  198529
#       家具    221058
#       技术    175014
# 云南    办公用品  123051
#       家具    174155
# ...            ...
# 青海    家具     25923
#       技术     22896
# 黑龙江   办公用品  473319
#       家具    497504
#       技术    375905
#
# [91 rows x 1 columns]

# %% [markdown]
# ### 7 - 数据透视｜多层
#
# 制作各省市「不同类别」产品的「销售总额」透视表

# %%
pd.pivot_table(df,values=['销售额'],index=['省/自治区'],columns=['类别'],aggfunc='sum')
# Out:
#             销售额
# 类别         办公用品        家具        技术
# 省/自治区
# 上海     198529.0  221058.0  175014.0
# 云南     123051.0  174155.0  144512.0
# 内蒙古     74058.0   95426.0   80333.0
# 北京     144232.0  127407.0   78913.0
# 吉林     215143.0  287498.0  394083.0
# 四川     111393.0   88297.0   70095.0
# 天津     142526.0  149452.0  191384.0
# 宁夏      19529.0   16449.0    5314.0
# 安徽     200511.0  215901.0  267841.0
# 山东     575520.0  664339.0  644271.0
# 山西     121458.0  175522.0  132103.0
# 广东     494643.0  530054.0  495840.0
# 广西     102625.0  165140.0  115824.0
# 新疆      38345.0   20520.0   14059.0
# 江苏     163919.0  152868.0   85101.0
# 江西      37114.0  107047.0   78051.0
# 河北     284739.0  306535.0  307765.0
# 河南     266916.0  294593.0  368856.0
# 浙江      84471.0   84436.0   97854.0
# 海南      34141.0   41225.0   24509.0
# 湖北     112230.0  118053.0  177758.0
# 湖南     197969.0  241804.0  281893.0
# 甘肃      54012.0   68657.0   72884.0
# 福建     142728.0  243289.0  234055.0
# 西藏        201.0       NaN       NaN
# 贵州       9713.0   29285.0   28023.0
# 辽宁     214994.0  270279.0  271404.0
# 重庆      71020.0   96318.0  116194.0
# 陕西     119169.0  187497.0   90142.0
# 青海      16718.0   25923.0   22896.0
# 黑龙江    473319.0  497504.0  375905.0

# %% [markdown]
# ### 8 - 数据透视｜综合
#
# 制作「各省市」、「不同类别」产品「销售量与销售额」的「均值与总和」的数据透视表，并在最后追加一行『合计』

# %%
pd.pivot_table(df,values=['销售额','数量'],index=['省/自治区','类别'],aggfunc=['sum','mean'],margins=True)
# Out:
#               sum                mean
#                数量       销售额        数量          销售额
# 省/自治区 类别
# 上海    办公用品    645    198529  3.706897  1140.971264
#       家具      343    221058  4.132530  2663.349398
#       技术      217    175014  3.616667  2916.900000
# 云南    办公用品    540    123051  3.913043   891.673913
#       家具      207    174155  4.224490  3554.183673
# ...           ...       ...       ...          ...
# 青海    技术       23     22896  3.833333  3816.000000
# 黑龙江   办公用品   1591    473319  3.657471  1088.089655
#       家具      651    497504  3.921687  2997.012048
#       技术      506    375905  3.442177  2557.176871
# All         37436  15984343  3.768093  1608.892099
#
# [92 rows x 4 columns]

# %%
pd.pivot_table(df,values=['销售额','数量'],index=['省/自治区'],columns=['类别'],aggfunc=['sum','mean'])#,margins=True)
# Out:
#            sum                                                          \
#             数量                               销售额
# 类别        办公用品      家具      技术    All       办公用品         家具         技术
# 省/自治区
# 上海       645.0   343.0   217.0   1205   198529.0   221058.0   175014.0
# 云南       540.0   207.0   194.0    941   123051.0   174155.0   144512.0
# 内蒙古      390.0   148.0   106.0    644    74058.0    95426.0    80333.0
# 北京       465.0   170.0   115.0    750   144232.0   127407.0    78913.0
# 吉林      1042.0   400.0   510.0   1952   215143.0   287498.0   394083.0
# 四川       525.0   198.0   126.0    849   111393.0    88297.0    70095.0
# 天津       709.0   244.0   219.0   1172   142526.0   149452.0   191384.0
# 宁夏        45.0    41.0    13.0     99    19529.0    16449.0     5314.0
# 安徽       987.0   352.0   344.0   1683   200511.0   215901.0   267841.0
# 山东      2518.0   952.0   843.0   4313   575520.0   664339.0   644271.0
# 山西       520.0   189.0   227.0    936   121458.0   175522.0   132103.0
# 广东      2126.0   743.0   771.0   3640   494643.0   530054.0   495840.0
# 广西       522.0   234.0   178.0    934   102625.0   165140.0   115824.0
# 新疆       118.0    44.0    36.0    198    38345.0    20520.0    14059.0
# 江苏       743.0   277.0   187.0   1207   163919.0   152868.0    85101.0
# 江西       229.0   115.0    91.0    435    37114.0   107047.0    78051.0
# 河北      1143.0   405.0   376.0   1924   284739.0   306535.0   307765.0
# 河南      1259.0   447.0   493.0   2199   266916.0   294593.0   368856.0
# 浙江       420.0   152.0   149.0    721    84471.0    84436.0    97854.0
# 海南       116.0    55.0    30.0    201    34141.0    41225.0    24509.0
# 湖北       638.0   237.0   261.0   1136   112230.0   118053.0   177758.0
# 湖南       951.0   351.0   390.0   1692   197969.0   241804.0   281893.0
# 甘肃       265.0   143.0   125.0    533    54012.0    68657.0    72884.0
# 福建       726.0   345.0   251.0   1322   142728.0   243289.0   234055.0
# 西藏         3.0     NaN     NaN      3      201.0        NaN        NaN
# 贵州        87.0    53.0    54.0    194     9713.0    29285.0    28023.0
# 辽宁      1130.0   524.0   488.0   2142   214994.0   270279.0   271404.0
# 重庆       438.0   182.0   163.0    783    71020.0    96318.0   116194.0
# 陕西       458.0   211.0   127.0    796   119169.0   187497.0    90142.0
# 青海        40.0    21.0    23.0     84    16718.0    25923.0    22896.0
# 黑龙江     1591.0   651.0   506.0   2748   473319.0   497504.0   375905.0
# All    21389.0  8434.0  7613.0  37436  4844936.0  5696531.0  5442876.0
#
#                      mean                                             \
#                        数量                                        销售额
# 类别          All      办公用品        家具        技术       All         办公用品
# 省/自治区
# 上海       594601  3.706897  4.132530  3.616667  3.801262  1140.971264
# 云南       441718  3.913043  4.224490  3.880000  3.970464   891.673913
# 内蒙古      249817  3.391304  3.363636  3.419355  3.389474   643.982609
# 北京       350552  3.750000  3.695652  3.484848  3.694581  1163.161290
# 吉林       896724  3.520270  3.773585  4.080000  3.703985   726.834459
# 四川       269785  3.947368  3.245902  3.230769  3.643777   837.541353
# 天津       483362  3.917127  4.206897  3.590164  3.906667   787.436464
# 宁夏        41292  3.750000  4.555556  3.250000  3.960000  1627.416667
# 安徽       684253  3.710526  3.485149  3.583333  3.634989   753.800752
# 山东      1884130  3.775112  3.733333  3.746667  3.760244   862.848576
# 山西       429083  3.880597  3.780000  3.721311  3.820408   906.402985
# 广东      1520537  3.908088  3.555024  3.816832  3.811518   909.270221
# 广西       383589  3.954545  4.034483  4.564103  4.078603   777.462121
# 新疆        72924  3.575758  4.000000  4.500000  3.807692  1161.969697
# 江苏       401888  3.849741  3.794521  3.895833  3.843949   849.321244
# 江西       222212  3.523077  4.791667  3.791667  3.849558   570.984615
# 河北       899039  3.968750  3.616071  3.580952  3.809901   988.677083
# 河南       930365  3.628242  3.519685  4.008130  3.683417   769.210375
# 浙江       266761  3.684211  3.534884  3.634146  3.641414   740.973684
# 海南        99875  3.314286  3.928571  3.333333  3.465517   975.457143
# 湖北       408041  3.666667  3.485294  3.954545  3.688312   645.000000
# 湖南       721666  3.629771  3.988636  3.900000  3.760000   755.606870
# 甘肃       195553  4.206349  4.468750  4.629630  4.368852   857.333333
# 福建       620072  3.801047  3.670213  3.438356  3.692737   747.267016
# 西藏          201  3.000000       NaN       NaN  3.000000   201.000000
# 贵州        67021  3.954545  4.416667  4.153846  4.127660   441.500000
# 辽宁       756677  3.741722  4.062016  3.935484  3.859459   711.900662
# 重庆       283532  3.876106  3.568627  3.975610  3.819512   628.495575
# 陕西       396808  3.816667  4.057692  3.256410  3.772512   993.075000
# 青海        65537  4.444444  3.000000  3.833333  3.818182  1857.555556
# 黑龙江     1346728  3.657471  3.921687  3.442177  3.673797  1088.089655
# All    15984343  3.763681  3.778674  3.768812  3.768093   852.531409
#
#
#
# 类别              家具           技术          All
# 省/自治区
# 上海     2663.349398  2916.900000  1875.712934
# 云南     3554.183673  2890.240000  1863.789030
# 内蒙古    2168.772727  2591.387097  1314.826316
# 北京     2769.717391  2391.303030  1726.857143
# 吉林     2712.245283  3152.664000  1701.563567
# 四川     1447.491803  1797.307692  1157.875536
# 天津     2576.758621  3137.442623  1611.206667
# 宁夏     1827.666667  1328.500000  1651.680000
# 安徽     2137.633663  2790.010417  1477.868251
# 山东     2605.250980  2863.426667  1642.659111
# 山西     3510.440000  2165.622951  1751.359184
# 广东     2536.143541  2454.653465  1592.185340
# 广西     2847.241379  2969.846154  1675.061135
# 新疆     1865.454545  1757.375000  1402.384615
# 江苏     2094.082192  1772.937500  1279.898089
# 江西     4460.291667  3252.125000  1966.477876
# 河北     2736.919643  2931.095238  1780.275248
# 河南     2319.629921  2998.829268  1558.400335
# 浙江     1963.627907  2386.682927  1347.277778
# 海南     2944.642857  2723.222222  1721.982759
# 湖北     1736.073529  2693.303030  1324.808442
# 湖南     2747.772727  2818.930000  1603.702222
# 甘肃     2145.531250  2699.407407  1602.893443
# 福建     2588.180851  3206.232877  1732.044693
# 西藏             NaN          NaN   201.000000
# 贵州     2440.416667  2155.615385  1425.978723
# 辽宁     2095.186047  2188.741935  1363.381982
# 重庆     1888.588235  2834.000000  1383.082927
# 陕西     3605.711538  2311.333333  1880.606635
# 青海     3703.285714  3816.000000  2978.954545
# 黑龙江    2997.012048  2557.176871  1800.438503
# All    2552.209229  2694.493069  1608.892099

# %% [markdown]
# ### 9 - 数据透视｜筛选
#
# 在上一题的基础上，查询 **「类别」** 等于 **「办公用品」** 的详情

# %%
ans(9)
# Out:
# table = pd.pivot_table(df,values = ['销售额','数量'],index = ['省/自治区','类别'],aggfunc = ['mean',sum],margins=True)
# table.query('类别 == ["办公用品"]')

# %%
pd.pivot_table(df,values = ['销售额','数量'],index = ['省/自治区','类别'],aggfunc = ['mean',sum],margins=True).query('类别 == ["办公用品"]')
# Out:
#                 mean                sum
#                   数量          销售额    数量     销售额
# 省/自治区 类别
# 上海    办公用品  3.706897  1140.971264   645  198529
# 云南    办公用品  3.913043   891.673913   540  123051
# 内蒙古   办公用品  3.391304   643.982609   390   74058
# 北京    办公用品  3.750000  1163.161290   465  144232
# 吉林    办公用品  3.520270   726.834459  1042  215143
# 四川    办公用品  3.947368   837.541353   525  111393
# 天津    办公用品  3.917127   787.436464   709  142526
# 宁夏    办公用品  3.750000  1627.416667    45   19529
# 安徽    办公用品  3.710526   753.800752   987  200511
# 山东    办公用品  3.775112   862.848576  2518  575520
# 山西    办公用品  3.880597   906.402985   520  121458
# 广东    办公用品  3.908088   909.270221  2126  494643
# 广西    办公用品  3.954545   777.462121   522  102625
# 新疆    办公用品  3.575758  1161.969697   118   38345
# 江苏    办公用品  3.849741   849.321244   743  163919
# 江西    办公用品  3.523077   570.984615   229   37114
# 河北    办公用品  3.968750   988.677083  1143  284739
# 河南    办公用品  3.628242   769.210375  1259  266916
# 浙江    办公用品  3.684211   740.973684   420   84471
# 海南    办公用品  3.314286   975.457143   116   34141
# 湖北    办公用品  3.666667   645.000000   638  112230
# 湖南    办公用品  3.629771   755.606870   951  197969
# 甘肃    办公用品  4.206349   857.333333   265   54012
# 福建    办公用品  3.801047   747.267016   726  142728
# 西藏    办公用品  3.000000   201.000000     3     201
# 贵州    办公用品  3.954545   441.500000    87    9713
# 辽宁    办公用品  3.741722   711.900662  1130  214994
# 重庆    办公用品  3.876106   628.495575   438   71020
# 陕西    办公用品  3.816667   993.075000   458  119169
# 青海    办公用品  4.444444  1857.555556    40   16718
# 黑龙江   办公用品  3.657471  1088.089655  1591  473319

# %% [markdown]
# ### 10 -数据透视｜逆透视

# %% [markdown]
# 逆透视就是将宽的表转换为长的表，例如将第 5 题的透视表进行逆透视，其中不需要转换的列为『数量』列
#
# - 资料
#     - https://vimsky.com/examples/usage/python-pandas-melt.html
#     - https://pandas.pydata.org/docs/reference/api/pandas.melt.html

# %%
# 尝试1
pd.pivot_table(df,values = ['销售额','利润','数量'],index = '类别',aggfunc = sum)
# Out:
#           利润     数量      销售额
# 类别
# 办公用品  752124  21389  4844936
# 家具    628052   8434  5696531
# 技术    742264   7613  5442876

# %%
table = pd.pivot_table(df,values = ['销售额','利润','数量'],index = '类别',aggfunc = sum)
table.melt(id_vars=['数量'],var_name='分类',value_name='金额')
# Out:
#       数量   分类       金额
# 0  21389   利润   752124
# 1   8434   利润   628052
# 2   7613   利润   742264
# 3  21389  销售额  4844936
# 4   8434  销售额  5696531
# 5   7613  销售额  5442876

# %%
table.melt(id_vars='数量',ignore_index=False)
# Out:
#          数量 variable    value
# 类别
# 办公用品  21389       利润   752124
# 家具     8434       利润   628052
# 技术     7613       利润   742264
# 办公用品  21389      销售额  4844936
# 家具     8434      销售额  5696531
# 技术     7613      销售额  5442876

# %%
table.melt(id_vars=['数量','利润'],ignore_index=False)
# Out:
#          数量      利润 variable    value
# 类别
# 办公用品  21389  752124      销售额  4844936
# 家具     8434  628052      销售额  5696531
# 技术     7613  742264      销售额  5442876

# %%
# （错误尝试）
pd.DataFrame(pd.pivot_table(df,values=['销售额','利润'],index=['省/自治区'],aggfunc='sum').stack())
# Out:
#                  0
# 省/自治区
# 上海    利润     87236
#       销售额   594601
# 云南    利润     83201
#       销售额   441718
# 内蒙古   利润    -20685
# ...            ...
# 陕西    销售额   396808
# 青海    利润      4354
#       销售额    65537
# 黑龙江   利润    228262
#       销售额  1346728
#
# [62 rows x 1 columns]

# %%
pd.DataFrame(pd.pivot_table(df,values=['销售额','利润'],index=['省/自治区'],aggfunc='sum').unstack())
# Out:
#                  0
#     省/自治区
# 利润  上海       87236
#     云南       83201
#     内蒙古     -20685
#     北京       57883
#     吉林      152504
# ...            ...
# 销售额 辽宁      756677
#     重庆      283532
#     陕西      396808
#     青海       65537
#     黑龙江    1346728
#
# [62 rows x 1 columns]

# %% [markdown]
# ## 数据合并

# %% [markdown]
# ### concat - 数据拼接

# %% [markdown]
# `concat`主要用于**数据拼接**，也是非常常用的一个操作
#
# 除了官方文档外很难找到比官方文档更好的练习
#
# 以下案例来源或基于 [👉官方文档](https://pandas.pydata.org/pandas-docs/version/0.20/merging.html) 中的案例修改而来
#
# 在练习之前应执行下方代码生成数据
#
# 并应预览不同数据的结构以及每题的图解（如果有）

# %% [markdown]
# https://cloud.tencent.com/developer/article/1640799

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['C0', 'C1', 'C2', 'C3'],
                    'D': ['D0', 'D1', 'D2', 'D3']},
                   index=[0, 1, 2, 3])


df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                    'B': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['C4', 'C5', 'C6', 'C7'],
                    'D': ['D4', 'D5', 'D6', 'D7']},
                   index=[4, 5, 6, 7])


df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],
                    'B': ['B8', 'B9', 'B10', 'B11'],
                    'C': ['C8', 'C9', 'C10', 'C11'],
                    'D': ['D8', 'D9', 'D10', 'D11']},
                   index=[8, 9, 10, 11])


df4 = pd.DataFrame({'B': ['B2', 'B3', 'B6', 'B7'],
                    'D': ['D2', 'D3', 'D6', 'D7'],
                    'F': ['F2', 'F3', 'F6', 'F7']},
                   index=[2, 3, 6, 7])

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#       A    B    C    D
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
df4
# Out:
#     B   D   F
# 2  B2  D2  F2
# 3  B3  D3  F3
# 6  B6  D6  F6
# 7  B7  D7  F7

# %% [markdown]
# #### 11 - <font color = '#FB8E00'>concat</font>｜默认拼接
#
# 拼接 df1 和 df2

# %%
pd.concat([df1,df2])
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %% [markdown]
# #### 12 - <font color = '#FB8E00'>concat</font>｜拼接多个
#
# 垂直拼接 `df1、df2、df3`，效果如下图所示
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_concat_basic.png)

# %%
pd.concat([df1,df2,df3])
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %% [markdown]
# #### 13 - <font color = '#FB8E00'>concat</font>｜重置索引
#
# 垂直拼接 df1 和 df4，并按顺序重新生成索引，
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_concat_ignore_index.png)

# %%
pd.concat([df1,df4],ignore_index=True)
# Out:
#      A   B    C   D    F
# 0   A0  B0   C0  D0  NaN
# 1   A1  B1   C1  D1  NaN
# 2   A2  B2   C2  D2  NaN
# 3   A3  B3   C3  D3  NaN
# 4  NaN  B2  NaN  D2   F2
# 5  NaN  B3  NaN  D3   F3
# 6  NaN  B6  NaN  D6   F6
# 7  NaN  B7  NaN  D7   F7

# %% [markdown]
# #### 14 - <font color = '#FB8E00'>concat</font>｜横向拼接
#
# 横向拼接 `df1、df4`，效果如下图所示
#
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_concat_axis1.png)

# %%
pd.concat([df1,df4],axis=1)
# Out:
#      A    B    C    D    B    D    F
# 0   A0   B0   C0   D0  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN
# 2   A2   B2   C2   D2   B2   D2   F2
# 3   A3   B3   C3   D3   B3   D3   F3
# 6  NaN  NaN  NaN  NaN   B6   D6   F6
# 7  NaN  NaN  NaN  NaN   B7   D7   F7

# %% [markdown]
# #### 15 - <font color = '#FB8E00'>concat</font>｜横向拼接（取交集）
#
# 在上一题的基础上，只取结果的交集
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_concat_axis1_inner.png)

# %%
pd.concat([df1,df4],axis=1,join='inner')
# Out:
#     A   B   C   D   B   D   F
# 2  A2  B2  C2  D2  B2  D2  F2
# 3  A3  B3  C3  D3  B3  D3  F3

# %% [markdown]
# #### 16 - <font color = '#FB8E00'>concat</font>｜横向拼接（取指定）
#
# 在 14 题基础上，只取包含 df1 索引的部分
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_concat_axis1_join_axes.png)

# %%
pd.concat([df1, df4], axis=1).reindex(df1.index)
# Out:
#     A   B   C   D    B    D    F
# 0  A0  B0  C0  D0  NaN  NaN  NaN
# 1  A1  B1  C1  D1  NaN  NaN  NaN
# 2  A2  B2  C2  D2   B2   D2   F2
# 3  A3  B3  C3  D3   B3   D3   F3

# %% [markdown]
# #### 17 - <font color = '#FB8E00'>concat</font>｜新增索引
#
# 拼接 `df1、df2、df3`，同时新增一个索引（`x、y、z`）来区分不同的表数据来源
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_concat_keys.png)

# %%
pd.concat([df1, df2, df3], keys=['x', 'y', 'z'])
# Out:
#         A    B    C    D
# x 0    A0   B0   C0   D0
#   1    A1   B1   C1   D1
#   2    A2   B2   C2   D2
#   3    A3   B3   C3   D3
# y 4    A4   B4   C4   D4
#   5    A5   B5   C5   D5
#   6    A6   B6   C6   D6
#   7    A7   B7   C7   D7
# z 8    A8   B8   C8   D8
#   9    A9   B9   C9   D9
#   10  A10  B10  C10  D10
#   11  A11  B11  C11  D11

# %% [markdown]
# ### merge - 数据连接

# %% [markdown]
# concat是拼接，merge则是连接，同样重要的一个操作
#
# 同样很难找到比官方文档更好的练习，以下案例来源或基于 [👉官方文档](https://pandas.pydata.org/pandas-docs/version/0.20/merging.html#database-style-dataframe-joining-merging) 中的案例修改而来
#
# 在练习之前应执行每题下方的代码生成数据
#
# 并应预览不同数据的结构以及每题的图解（如果有）

# %% [markdown]
# #### 18 - <font color = '#1B85FF' >merge</font>｜按单键
#
# 根据 `key` 连接 `left` 和 `right`
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_merge_on_key.png)

# %%
left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})

right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key   A   B
# 0  K0  A0  B0
# 1  K1  A1  B1
# 2  K2  A2  B2
# 3  K3  A3  B3

# %%
right
# Out:
#   key   C   D
# 0  K0  C0  D0
# 1  K1  C1  D1
# 2  K2  C2  D2
# 3  K3  C3  D3

# %%
ans(18)
# Out:
# pd.merge(left, right, on='key')

# %%
pd.merge(left, right, on='key')
# Out:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3

# %% [markdown]
# #### 19 - <font color = '#1B85FF' >merge</font>｜按多键
#
# 根据 `key1` 和 `key2` 连接 `left` 和 `right`
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_merge_on_key_multiple.png)

# %%
left = pd.DataFrame({'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1'],
                     'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3']})


right = pd.DataFrame({'key1': ['K0', 'K1', 'K1', 'K2'],
                      'key2': ['K0', 'K0', 'K0', 'K0'],
                      'C': ['C0', 'C1', 'C2', 'C3'],
                      'D': ['D0', 'D1', 'D2', 'D3']})

# %%
left
# Out:
#   key1 key2   A   B
# 0   K0   K0  A0  B0
# 1   K0   K1  A1  B1
# 2   K1   K0  A2  B2
# 3   K2   K1  A3  B3

# %%
right
# Out:
#   key1 key2   C   D
# 0   K0   K0  C0  D0
# 1   K1   K0  C1  D1
# 2   K1   K0  C2  D2
# 3   K2   K0  C3  D3

# %%
pd.merge(left, right, on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %% [markdown]
# #### 20 - <font color = '#1B85FF' >merge</font>｜左外连接
#
#
# 如下图所示的结果连接 left 和 right，保留左表全部键
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_merge_on_key_left.png)

# %%
pd.merge(left, right, on=['key1', 'key2'],how='left')
# Out:
#   key1 key2   A   B    C    D
# 0   K0   K0  A0  B0   C0   D0
# 1   K0   K1  A1  B1  NaN  NaN
# 2   K1   K0  A2  B2   C1   D1
# 3   K1   K0  A2  B2   C2   D2
# 4   K2   K1  A3  B3  NaN  NaN

# %% [markdown]
# #### 21 - <font color = '#1B85FF' >merge</font>｜右外连接
#
#
# 如下图所示的结果连接 left 和 right，保留右表全部键
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_merge_on_key_right.png)

# %%
pd.merge(left, right, on=['key1', 'key2'],how='right')
# Out:
#   key1 key2    A    B   C   D
# 0   K0   K0   A0   B0  C0  D0
# 1   K1   K0   A2   B2  C1  D1
# 2   K1   K0   A2   B2  C2  D2
# 3   K2   K0  NaN  NaN  C3  D3

# %% [markdown]
# #### 22 - <font color = '#1B85FF' >merge</font>｜全外连接
#
#
# 如下图所示的结果连接 left 和 right，保留全部键
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_merge_on_key_outer.png)

# %%
pd.merge(left, right, how='outer', on=['key1', 'key2'])
# Out:
#   key1 key2    A    B    C    D
# 0   K0   K0   A0   B0   C0   D0
# 1   K0   K1   A1   B1  NaN  NaN
# 2   K1   K0   A2   B2   C1   D1
# 3   K1   K0   A2   B2   C2   D2
# 4   K2   K1   A3   B3  NaN  NaN
# 5   K2   K0  NaN  NaN   C3   D3

# %% [markdown]
# #### 23 - <font color = '#1B85FF' >merge</font>｜内连接
#
#
# 如下图所示的结果连接 left 和 right，保留交集
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_merge_on_key_inner.png)

# %%
pd.merge(left, right, how='inner', on=['key1', 'key2'])
# Out:
#   key1 key2   A   B   C   D
# 0   K0   K0  A0  B0  C0  D0
# 1   K1   K0  A2  B2  C1  D1
# 2   K1   K0  A2  B2  C2  D2

# %% [markdown]
# #### 24 - <font color = '#1B85FF' >merge</font>｜重复索引
#
#
# 重新产生数据并按下图所示进行连接
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_merge_overlapped_suffix.png)

# %%
left = pd.DataFrame({'k': ['K0', 'K1', 'K2'], 'v': [1, 2, 3]})

right = pd.DataFrame({'k': ['K0', 'K0', 'K3'], 'v': [4, 5, 6]})

# %%
left
# Out:
#     k  v
# 0  K0  1
# 1  K1  2
# 2  K2  3

# %%
right
# Out:
#     k  v
# 0  K0  4
# 1  K0  5
# 2  K3  6

# %%
pd.merge(left, right, on='k', suffixes=['_l', '_r'])
# Out:
#     k  v_l  v_r
# 0  K0    1    4
# 1  K0    1    5

# %% [markdown]
# ### join - 组合

# %% [markdown]
# 最后一个数据合并的常用且重要的操作是`join`
#
# 同样很难找到比官方文档更好的练习，以下案例来源或基于 [👉官方文档](https://pandas.pydata.org/pandas-docs/version/0.20/merging.html#database-style-dataframe-joining-merging) 中的案例修改而来
#
# 在练习之前应执行每题下方的代码生成数据
#
# 并应预览不同数据的结构以及每题的图解（如果有）

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2'],
                     'B': ['B0', 'B1', 'B2']},
                     index=['K0', 'K1', 'K2'])


right = pd.DataFrame({'C': ['C0', 'C2', 'C3'],
                      'D': ['D0', 'D2', 'D3']},
                      index=['K0', 'K2', 'K3'])

# %%
left
# Out:
#      A   B
# K0  A0  B0
# K1  A1  B1
# K2  A2  B2

# %%
right
# Out:
#      C   D
# K0  C0  D0
# K2  C2  D2
# K3  C3  D3

# %% [markdown]
# #### 25 -  <font color ='#27BE49'>join</font>｜左对齐
#
# 合并 left 和 right，并按照 left 的索引进行对齐

# %% [markdown]
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_join.png)

# %%
left.join(right)
# Out:
#      A   B    C    D
# K0  A0  B0   C0   D0
# K1  A1  B1  NaN  NaN
# K2  A2  B2   C2   D2

# %% [markdown]
# #### 26 - <font color ='#27BE49'>join</font>｜左对齐（外连接）
#
# 按下图所示进行连接
#
# 思考：merge 做法
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_join_outer.png)

# %%
left.join(right, how='outer')
# Out:
#       A    B    C    D
# K0   A0   B0   C0   D0
# K1   A1   B1  NaN  NaN
# K2   A2   B2   C2   D2
# K3  NaN  NaN   C3   D3

# %% [markdown]
# #### 27 - <font color ='#27BE49'>join</font>｜左对齐（内连接）
#
# 按下图所示进行连接
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_join_inner.png)

# %%
left.join(right, how='inner')
# Out:
#      A   B   C   D
# K0  A0  B0  C0  D0
# K2  A2  B2  C2  D2

# %% [markdown]
# #### 28 - <font color ='#27BE49'>join</font>｜按索引
#
# 重新产生数据并按下图所示进行连接（根据 `key`）
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_join_key_columns.png)

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'key': ['K0', 'K1', 'K0', 'K1']})


right = pd.DataFrame({'C': ['C0', 'C1'],
                      'D': ['D0', 'D1']},
                      index=['K0', 'K1'])

# %%
left.join(right, on='key')
# Out:
#     A   B key   C   D
# 0  A0  B0  K0  C0  D0
# 1  A1  B1  K1  C1  D1
# 2  A2  B2  K0  C0  D0
# 3  A3  B3  K1  C1  D1

# %% [markdown]
# #### 29 - <font color ='#27BE49'>join</font>｜按索引（多个）
#
# 重新产生数据并按下图所示进行连接（根据 `key1` 和 `key2`）
#
# ![](https://pandas.pydata.org/pandas-docs/version/0.20/_images/merging_join_multikeys.png)

# %%
left = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                     'B': ['B0', 'B1', 'B2', 'B3'],
                     'key1': ['K0', 'K0', 'K1', 'K2'],
                     'key2': ['K0', 'K1', 'K0', 'K1']})


index = pd.MultiIndex.from_tuples([('K0', 'K0'), ('K1', 'K0'),
                                  ('K2', 'K0'), ('K2', 'K1')])


right = pd.DataFrame({'C': ['C0', 'C1', 'C2', 'C3'],
                   'D': ['D0', 'D1', 'D2', 'D3']},
                  index=index)

# %%
left.join(right, on=['key1', 'key2'])
# Out:
#     A   B key1 key2    C    D
# 0  A0  B0   K0   K0   C0   D0
# 1  A1  B1   K0   K1  NaN  NaN
# 2  A2  B2   K1   K0   C1   D1
# 3  A3  B3   K2   K1   C3   D3
