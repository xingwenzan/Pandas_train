# %% [markdown]
# # pandas 进阶修炼
# <br>
#
# 本习题基于 `pandas` 版本 `1.1.3`，所有内容应当在 `Jupyter Notebook` 中执行以获得最佳效果。
#
# 不同版本之间写法可能会有少许不同，如若碰到此情况，你应该学会如何自行检索解决。

# %% [markdown]
# # 1 - 数据加载与存储

# %% [markdown]
# 是的，常常被忽略的「<font color=#E36C07>**数据加载与存储**</font>」也大有门道且值得作为本套习题的开门之章。
#
# 在一次数据分析的过程中，你可能只会读取或存储一两次数据集。
#
# **但若能灵活掌握各项设置，在读取阶段就将数据筛选、匹配、格式指定等操作完成，有时会为我们节省大量时间。**
#
# 在本节习题中，我将 pandas 数据分析中常见的数据读取与存储操作进行整理。
#
# <font color=#E36C07>**既可以用于巩固、学习各种操作，也可以作为速查手册使用**</font>。

# %% [markdown]
# ## 初始化
#
# <br>
#
# 该 `Notebook` 版本为**习题+答案版**
#
#
# <font color=#E36C07>**请执行下方单元格以初始化读取本节习题的答案**</font>
#
# 执行完毕后，你可以使用  <font color=#E36C07> **ans(1)** </font>  来查看第 1 题的参考解答，其余习题类似。
#
# 注意：所有答案并非固定（唯一），我提供的答案仅供参考（并非推荐答案或者最优解）！

# %%
# !pip install inits
# Out:
# ERROR: Could not find a version that satisfies the requirement inits (from versions: none)
# ERROR: No matching distribution found for inits
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\86159\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import sys
import pandas as pd
sys.path.append('../document/')
#from inits import initialize,ans

#res = initialize("../document/answer-1.txt")

# %% [markdown]
# ## 1-1 数据读取

# %% [markdown]
# ### 1 读取 Excel 文件
#
# <br>
#
# - 读取当前目录下 `某招聘网站数据.csv` 文件
#
# - 读取当前目录下 `TOP250.xlsx` 文件
#
# **注意**：使用 `pandas` 读取 `CSV` 与 读取 `xlsx` 格式的 `Excel` 文件方法大致相同
#
# 因此接下来与 `Excel` 相关的操作均以 `CSV` 格式进行出题。

# %%
data = pd.read_csv("某招聘网站数据.csv")
data = pd.read_excel("TOP250.xlsx")

# %% [markdown]
# ### 2 读取 Excel 文件｜指定位置
#
# 在大多数情况下，我们会将 `notebook` 和数据源文件放在同一个目录（文件夹下），这样直接使用`pd.read_xxx("文件名")`即可成功读取。
#
# 但有时需要读取的文件和 `notebook` 不在同一个目录下，这时可以使用绝对路径或者相对本 `notebook` 的路径。
#
# 现在请读取本套习题中第二章节下的数据，即 `2 - 个性化显示设置/data.csv`

# %%
data = pd.read_csv('../2-个性化显示设置/data.csv')
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 1     5204912         数据建模      50735    150-500人            电商           B轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 3     6496141         数据分析      26564   500-2000人            电商        D轮及以上
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司
#
#                     companyLabelList  firstType secondType thirdType  ...  \
# 0   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...
# 1   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...
# 2   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...
# 3  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...
# 4   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
#
#   plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 0  NaN      0       0       0              NaN                   NaN
# 1  NaN      0       0       0              NaN                   NaN
# 2  NaN      0       0       0              NaN                   NaN
# 3  NaN      0       0       0              NaN                   NaN
# 4  NaN      0       0       0              NaN                   NaN
#
#   isHotHire  count aggregatePositionIds famousCompany
# 0         0      0                   []         False
# 1         0      0                   []         False
# 2         0      0                   []         False
# 3         0      0                   []          True
# 4         0      0                   []          True
#
# [5 rows x 52 columns]

# %% [markdown]
# ###  3 读取 Excel 文件｜指定行（顺序）
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 <font color = '#5F5FFC'>前20行</font>

# %%
data = pd.read_csv('./某招聘网站数据.csv',nrows=20)
data
# Out:
#     positionId      positionName  companyId companySize industryField  \
# 0      6802721              数据分析     475770     50-150人      移动互联网,电商
# 1      5204912              数据建模      50735    150-500人            电商
# 2      6877668              数据分析     100125     2000人以上    移动互联网,企业服务
# 3      6496141              数据分析      26564   500-2000人            电商
# 4      6467417              数据分析      29211     2000人以上         物流丨运输
# 5      6882347              数据分析      94826     50-150人      移动互联网,社交
# 6      6841659              数据分析     348784     50-150人      移动互联网,电商
# 7      6764018           数据建模工程师      13163   500-2000人         移动互联网
# 8      6458372            数据分析专家      34132    150-500人     数据服务,广告营销
# 9      6786904             数据分析师      13163   500-2000人         移动互联网
# 10     6804629             数据分析师      34132    150-500人     数据服务,广告营销
# 11     6847013  大数据分析工程师(J11108)      55046     2000人以上    移动互联网,企业服务
# 12     6763962           数据分析工程师      13163   500-2000人         移动互联网
# 13     6804489           资深数据分析师      34132    150-500人     数据服务,广告营销
# 14     6657285             数据分析师       7461     2000人以上          企业服务
# 15     6882983       产品运营（偏数据分析）       7461     2000人以上          企业服务
# 16     6486988       资深数据分析师（杭州）       7461     2000人以上          企业服务
# 17     5519962           大数据建模总监      50735    150-500人            电商
# 18     5559894   数据建模专家-杭州-01546       6502   500-2000人     信息安全,数据服务
# 19     6702852      数据分析专家（游戏业务）        593     2000人以上      移动互联网,游戏
#
#    financeStage                     companyLabelList  firstType secondType  \
# 0            A轮     ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1            B轮     ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2          上市公司     ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3         D轮及以上    ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4          上市公司     ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# 5            B轮     ['股票期权', '扁平管理', '五险一金', '岗位晋升']  产品|需求|项目类       数据分析
# 6            A轮     ['大牛团队', '扁平管理', '年底双薪', '股票期权']  产品|需求|项目类       数据分析
# 7          上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 8            A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 9          上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 10           A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 11         上市公司     ['技能培训', '年底双薪', '带薪年假', '岗位晋升']  开发|测试|运维类       数据开发
# 12         上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 13           A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  开发|测试|运维类       数据开发
# 14         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  产品|需求|项目类       数据分析
# 15         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  运营|编辑|客服类         运营
# 16         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  开发|测试|运维类       数据开发
# 17           B轮     ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 18        D轮及以上     ['技能培训', '股票期权', '绩效奖金', '岗位晋升']  开发|测试|运维类       数据开发
# 19        不需要融资     ['五险一金', '交通补助', '绩效奖金', '节日礼物']  开发|测试|运维类       数据开发
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0       数据分析  ...  NaN      0       0       0              NaN
# 1         建模  ...  NaN      0       0       0              NaN
# 2       数据分析  ...  NaN      0       0       0              NaN
# 3       数据分析  ...  NaN      0       0       0              NaN
# 4       数据分析  ...  NaN      0       0       0              NaN
# 5       数据分析  ...  NaN      0       0       0              NaN
# 6       数据分析  ...  NaN      0       0       0              NaN
# 7         建模  ...  NaN      0       0       0              NaN
# 8     其他数据分析  ...  NaN      0       0       0              NaN
# 9      BI工程师  ...  NaN      0       0       0              NaN
# 10      数据分析  ...  NaN      0       0       0              NaN
# 11      数据分析  ...  NaN      0       0       0              NaN
# 12      数据分析  ...  NaN      0       0       0              NaN
# 13      数据分析  ...  NaN      0       0       0              NaN
# 14      数据分析  ...  NaN      0       0       0              NaN
# 15      数据运营  ...  NaN      0       0       0              NaN
# 16      数据分析  ...  NaN      0       0       0              NaN
# 17        建模  ...  NaN      0       0       0              NaN
# 18        建模  ...  NaN      0       0       0              NaN
# 19      数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                    NaN         0      0                   []         False
# 1                    NaN         0      0                   []         False
# 2                    NaN         0      0                   []         False
# 3                    NaN         0      0                   []          True
# 4                    NaN         0      0                   []          True
# 5                    NaN         0      0                   []         False
# 6                    NaN         0      0                   []         False
# 7                    NaN         0      0                   []          True
# 8                    NaN         0      0                   []         False
# 9                    NaN         0      0                   []          True
# 10                   NaN         0      0                   []         False
# 11                   NaN         0      0                   []         False
# 12                   NaN         0      0                   []          True
# 13                   NaN         0      0                   []         False
# 14                   NaN         0      0                   []          True
# 15                   NaN         0      0                   []          True
# 16                   NaN         0      0                   []          True
# 17                   NaN         0      0                   []         False
# 18                   NaN         0      0                   []         False
# 19                   NaN         0      0                   []          True
#
# [20 rows x 52 columns]

# %% [markdown]
# ###  4 读取 Excel 文件｜指定行（跳过）
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件并<font color = '#5F5FFC'>跳过前20行</font>

# %%
data = pd.read_csv('./某招聘网站数据.csv',skiprows=20)
data.head()
# Out:
#    6702852 数据分析专家（游戏业务）     593   2000人以上  移动互联网,游戏  不需要融资  \
# 0  6829277      资深数据分析师     593   2000人以上  移动互联网,游戏  不需要融资
# 1  6267370       数据分析专家   31544  150-500人      数据服务  不需要融资
# 2  5927901       数据分析经理      62   2000人以上     文娱丨内容     C轮
# 3  6862245       数据分析专家  473950   50-150人     移动互联网    未融资
# 4  5604926        数据分析师  143884   50-150人  移动互联网,金融     A轮
#
#        ['五险一金', '交通补助', '绩效奖金', '节日礼物']  开发|测试|运维类    数据开发    数据分析  ...  \
# 0      ['五险一金', '交通补助', '绩效奖金', '节日礼物']  产品|需求|项目类  高端产品职位  数据分析专家  ...
# 1    ['专业红娘牵线', '节日礼物', '技能培训', '岗位晋升']  开发|测试|运维类    数据开发    数据分析  ...
# 2  ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类    产品经理  其他产品经理  ...
# 3                                    []  产品|需求|项目类    数据分析    数据分析  ...
# 4      ['股票期权', '带薪年假', '绩效奖金', '年底双薪']  开发|测试|运维类    数据开发    数据分析  ...
#
#   Unnamed: 42 0.3 0.4 0.5 Unnamed: 46 Unnamed: 47 0.6  0.7  []   TRUE
# 0         NaN   0   0   0         NaN         NaN   0    0  []   True
# 1         NaN   0   0   0         NaN         NaN   0    0  []  False
# 2         NaN   0   0   0         NaN         NaN   0    0  []   True
# 3         NaN   0   0   0         NaN         NaN   0    0  []  False
# 4         NaN   0   0   0         NaN         NaN   0    0  []  False
#
# [5 rows x 52 columns]

# %% [markdown]
# ###  5 读取 Excel 文件｜指定行（条件）
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件中全部<font color = '#5F5FFC'>偶数行</font>
#
# 思考：如果是读取全部奇数行，或者更多满足指定条件的行呢？

# %%
data = pd.read_csv('./某招聘网站数据.csv',skiprows=lambda x:x % 2 !=0)
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     5204912         数据建模      50735    150-500人            电商           B轮
# 1     6496141         数据分析      26564   500-2000人            电商        D轮及以上
# 2     6882347         数据分析      94826     50-150人      移动互联网,社交           B轮
# 3     6764018      数据建模工程师      13163   500-2000人         移动互联网         上市公司
# 4     6786904        数据分析师      13163   500-2000人         移动互联网         上市公司
#
#                     companyLabelList  firstType secondType thirdType  ...  \
# 0   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...
# 1  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...
# 2   ['股票期权', '扁平管理', '五险一金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
# 3   ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发        建模  ...
# 4   ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发     BI工程师  ...
#
#   plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 0  NaN      0       0       0              NaN                   NaN
# 1  NaN      0       0       0              NaN                   NaN
# 2  NaN      0       0       0              NaN                   NaN
# 3  NaN      0       0       0              NaN                   NaN
# 4  NaN      0       0       0              NaN                   NaN
#
#   isHotHire  count aggregatePositionIds famousCompany
# 0         0      0                   []         False
# 1         0      0                   []          True
# 2         0      0                   []         False
# 3         0      0                   []          True
# 4         0      0                   []          True
#
# [5 rows x 52 columns]

# %% [markdown]
# ![公众号：早起Python](http://liuzaoqi.oss-cn-beijing.aliyuncs.com/2021/09/18/16319660121648.jpg?域名/sample.jpg?x-oss-process=style/stylename)

# %% [markdown]
# ### 6 读取 Excel 文件｜指定列（列号）
#
# <br>
#
# **根据指定列号读取**
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的第 `1、3、5` 列

# %%
data = pd.read_csv('./某招聘网站数据.csv',usecols=[1,3,5])
data.head()
# Out:
#   positionName companySize financeStage
# 0         数据分析     50-150人           A轮
# 1         数据建模    150-500人           B轮
# 2         数据分析     2000人以上         上市公司
# 3         数据分析   500-2000人        D轮及以上
# 4         数据分析     2000人以上         上市公司

# %% [markdown]
# ###  7 读取 Excel 文件｜指定列（列名）
#
# <br>
#
# **根据指定列名读取**
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 `positionId、positionName、salary` 列

# %%
data = pd.read_csv('./某招聘网站数据.csv',usecols=['positionId','positionName','salary'])
data.head()
# Out:
#    positionId positionName  salary
# 0     6802721         数据分析   37500
# 1     5204912         数据建模   15000
# 2     6877668         数据分析    3500
# 3     6496141         数据分析   45000
# 4     6467417         数据分析   30000

# %% [markdown]
# ###  8 读取 Excel 文件｜指定列（匹配）
#
# <br>
#
# **根据指定列名匹配读取**
#
# 让我们来个更难一点的，还是读取 `某招聘网站数据.csv` 文件，但现在有一个 list 中包含多个字段👇
#
# `usecols = ['positionId','test','positionName', 'test1','salary']`
#
# 如果 `usecols` 中的列名存在于 `某招聘网站数据.csv` 中，则读取。

# %%
usecols = ['positionId','test','positionName', 'test1','salary']
data = pd.read_csv('./某招聘网站数据.csv',usecols = lambda x: x in set(usecols))
data.head()
# Out:
#    positionId positionName  salary
# 0     6802721         数据分析   37500
# 1     5204912         数据建模   15000
# 2     6877668         数据分析    3500
# 3     6496141         数据分析   45000
# 4     6467417         数据分析   30000

# %% [markdown]
# ### 9 读取 Excel 文件｜指定索引
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并在读取时将 `positionId` 设置为索引列

# %%
data = pd.read_csv('./某招聘网站数据.csv',index_col=['positionId'])
data.head()
# Out:
#            positionName  companyId companySize industryField financeStage  \
# positionId
# 6802721            数据分析     475770     50-150人      移动互联网,电商           A轮
# 5204912            数据建模      50735    150-500人            电商           B轮
# 6877668            数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 6496141            数据分析      26564   500-2000人            电商        D轮及以上
# 6467417            数据分析      29211     2000人以上         物流丨运输         上市公司
#
#                              companyLabelList  firstType secondType thirdType  \
# positionId
# 6802721      ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析
# 5204912      ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模
# 6877668      ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析
# 6496141     ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析
# 6467417      ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析
#
#                              skillLables  ... plus pcShow appShow deliver  \
# positionId                                ...
# 6802721     ['SQL', '数据库', '数据运营', 'BI']  ...  NaN      0       0       0
# 5204912                   ['算法', '数据架构']  ...  NaN      0       0       0
# 6877668           ['数据库', '数据分析', 'SQL']  ...  NaN      0       0       0
# 6496141                               []  ...  NaN      0       0       0
# 6467417           ['BI', '数据分析', '数据运营']  ...  NaN      0       0       0
#
#            gradeDescription promotionScoreExplain  isHotHire count  \
# positionId
# 6802721                 NaN                   NaN          0     0
# 5204912                 NaN                   NaN          0     0
# 6877668                 NaN                   NaN          0     0
# 6496141                 NaN                   NaN          0     0
# 6467417                 NaN                   NaN          0     0
#
#            aggregatePositionIds famousCompany
# positionId
# 6802721                      []         False
# 5204912                      []         False
# 6877668                      []         False
# 6496141                      []          True
# 6467417                      []          True
#
# [5 rows x 51 columns]

# %% [markdown]
# ###  10 读取 Excel 文件｜指定标题
#
# <br>
#
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 `positionId、positionName、salary` 列，并将标题设置为 `ID、岗位名称、薪资`

# %%
data = pd.read_csv('./某招聘网站数据.csv',usecols=[0,1,17],names=['ID','岗位名称','薪资']) # 奇怪，为啥usecols用序号好使，写名就不好使
data.head()
# Out:
#            ID          岗位名称      薪资
# 0  positionId  positionName  salary
# 1     6802721          数据分析   37500
# 2     5204912          数据建模   15000
# 3     6877668          数据分析    3500
# 4     6496141          数据分析   45000

# %%
data = pd.read_csv('./某招聘网站数据.csv',usecols=[0,1,17],header=0,names=['ID','岗位名称','薪资'])
data.head()
# Out:
#         ID  岗位名称     薪资
# 0  6802721  数据分析  37500
# 1  5204912  数据建模  15000
# 2  6877668  数据分析   3500
# 3  6496141  数据分析  45000
# 4  6467417  数据分析  30000

# %% [markdown]
# ###  11 读取 Excel 文件｜缺失值转换
#
# <br>
#
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**并不将缺失值标记为 `NA`**
#
# 思考：为什么要这样做？

# %%
data = pd.read_csv('./某招聘网站数据.csv',keep_default_na= False)
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 1     5204912         数据建模      50735    150-500人            电商           B轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 3     6496141         数据分析      26564   500-2000人            电商        D轮及以上
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司
#
#                     companyLabelList  firstType secondType thirdType  ...  \
# 0   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...
# 1   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...
# 2   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...
# 3  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...
# 4   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
#
#   plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 0           0       0       0
# 1           0       0       0
# 2           0       0       0
# 3           0       0       0
# 4           0       0       0
#
#   isHotHire  count aggregatePositionIds famousCompany
# 0         0      0                   []         False
# 1         0      0                   []         False
# 2         0      0                   []         False
# 3         0      0                   []          True
# 4         0      0                   []          True
#
# [5 rows x 52 columns]

# %%
data = pd.read_csv('./某招聘网站数据.csv',keep_default_na= True)
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 1     5204912         数据建模      50735    150-500人            电商           B轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 3     6496141         数据分析      26564   500-2000人            电商        D轮及以上
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司
#
#                     companyLabelList  firstType secondType thirdType  ...  \
# 0   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...
# 1   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...
# 2   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...
# 3  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...
# 4   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
#
#   plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 0  NaN      0       0       0              NaN                   NaN
# 1  NaN      0       0       0              NaN                   NaN
# 2  NaN      0       0       0              NaN                   NaN
# 3  NaN      0       0       0              NaN                   NaN
# 4  NaN      0       0       0              NaN                   NaN
#
#   isHotHire  count aggregatePositionIds famousCompany
# 0         0      0                   []         False
# 1         0      0                   []         False
# 2         0      0                   []         False
# 3         0      0                   []          True
# 4         0      0                   []          True
#
# [5 rows x 52 columns]

# %% [markdown]
# ###  12 读取 Excel 文件｜缺失值标记
#
# <br>
#
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**并将`[]`标记为缺失值**

# %%
data = pd.read_csv('./某招聘网站数据.csv',na_values=['[]'])
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 1     5204912         数据建模      50735    150-500人            电商           B轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 3     6496141         数据分析      26564   500-2000人            电商        D轮及以上
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司
#
#                     companyLabelList  firstType secondType thirdType  ...  \
# 0   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...
# 1   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...
# 2   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...
# 3  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...
# 4   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
#
#   plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 0  NaN      0       0       0              NaN                   NaN
# 1  NaN      0       0       0              NaN                   NaN
# 2  NaN      0       0       0              NaN                   NaN
# 3  NaN      0       0       0              NaN                   NaN
# 4  NaN      0       0       0              NaN                   NaN
#
#   isHotHire  count aggregatePositionIds famousCompany
# 0         0      0                  NaN         False
# 1         0      0                  NaN         False
# 2         0      0                  NaN         False
# 3         0      0                  NaN          True
# 4         0      0                  NaN          True
#
# [5 rows x 52 columns]

# %% [markdown]
# ### 13 读取 Excel 文件｜忽略缺失值
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**但不处理缺失值**
#
# 思考：和之前的有什么不同，为什么这么做？

# %%
data = pd.read_csv('./某招聘网站数据.csv',na_filter=False)
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 1     5204912         数据建模      50735    150-500人            电商           B轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 3     6496141         数据分析      26564   500-2000人            电商        D轮及以上
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司
#
#                     companyLabelList  firstType secondType thirdType  ...  \
# 0   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...
# 1   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...
# 2   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...
# 3  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...
# 4   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
#
#   plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 0           0       0       0
# 1           0       0       0
# 2           0       0       0
# 3           0       0       0
# 4           0       0       0
#
#   isHotHire  count aggregatePositionIds famousCompany
# 0         0      0                   []         False
# 1         0      0                   []         False
# 2         0      0                   []         False
# 3         0      0                   []          True
# 4         0      0                   []          True
#
# [5 rows x 52 columns]

# %%
data = pd.read_csv('./某招聘网站数据.csv',na_filter=True)
data.head()
# Out:
#    positionId positionName  companyId companySize industryField financeStage  \
# 0     6802721         数据分析     475770     50-150人      移动互联网,电商           A轮
# 1     5204912         数据建模      50735    150-500人            电商           B轮
# 2     6877668         数据分析     100125     2000人以上    移动互联网,企业服务         上市公司
# 3     6496141         数据分析      26564   500-2000人            电商        D轮及以上
# 4     6467417         数据分析      29211     2000人以上         物流丨运输         上市公司
#
#                     companyLabelList  firstType secondType thirdType  ...  \
# 0   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...
# 1   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...
# 2   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...
# 3  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...
# 4   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
#
#   plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 0  NaN      0       0       0              NaN                   NaN
# 1  NaN      0       0       0              NaN                   NaN
# 2  NaN      0       0       0              NaN                   NaN
# 3  NaN      0       0       0              NaN                   NaN
# 4  NaN      0       0       0              NaN                   NaN
#
#   isHotHire  count aggregatePositionIds famousCompany
# 0         0      0                   []         False
# 1         0      0                   []         False
# 2         0      0                   []         False
# 3         0      0                   []          True
# 4         0      0                   []          True
#
# [5 rows x 52 columns]

# %% [markdown]
# ### 14 读取 Excel 文件｜指定格式
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并将 `positionId,companyId` 设置为字符串格式

# %%
data = pd.read_csv('./某招聘网站数据.csv'
    ,dtype={'positionId':str,'companyId':str})
data.head()
# Out:
#   positionId positionName companyId companySize industryField financeStage  \
# 0    6802721         数据分析    475770     50-150人      移动互联网,电商           A轮
# 1    5204912         数据建模     50735    150-500人            电商           B轮
# 2    6877668         数据分析    100125     2000人以上    移动互联网,企业服务         上市公司
# 3    6496141         数据分析     26564   500-2000人            电商        D轮及以上
# 4    6467417         数据分析     29211     2000人以上         物流丨运输         上市公司
#
#                     companyLabelList  firstType secondType thirdType  ...  \
# 0   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析      数据分析  ...
# 1   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发        建模  ...
# 2   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析      数据分析  ...
# 3  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发      数据分析  ...
# 4   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析      数据分析  ...
#
#   plus pcShow appShow deliver gradeDescription promotionScoreExplain  \
# 0  NaN      0       0       0              NaN                   NaN
# 1  NaN      0       0       0              NaN                   NaN
# 2  NaN      0       0       0              NaN                   NaN
# 3  NaN      0       0       0              NaN                   NaN
# 4  NaN      0       0       0              NaN                   NaN
#
#   isHotHire  count aggregatePositionIds famousCompany
# 0         0      0                   []         False
# 1         0      0                   []         False
# 2         0      0                   []         False
# 3         0      0                   []          True
# 4         0      0                   []          True
#
# [5 rows x 52 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   positionId             105 non-null    object
#  1   positionName           105 non-null    object
#  2   companyId              105 non-null    object
#  3   companySize            105 non-null    object
#  4   industryField          105 non-null    object
#  5   financeStage           105 non-null    object
#  6   companyLabelList       105 non-null    object
#  7   firstType              105 non-null    object
#  8   secondType             105 non-null    object
#  9   thirdType              105 non-null    object
#  10  skillLables            105 non-null    object
#  11  positionLables         105 non-null    object
#  12  industryLables         105 non-null    object
#  13  createTime             105 non-null    object
#  14  formatCreateTime       105 non-null    object
#  15  district               105 non-null    object
#  16  businessZones          53 non-null     object
#  17  salary                 105 non-null    int64
#  18  workYear               105 non-null    object
#  19  jobNature              105 non-null    object
#  20  education              105 non-null    object
#  21  positionAdvantage      105 non-null    object
#  22  imState                105 non-null    object
#  23  lastLogin              105 non-null    object
#  24  publisherId            105 non-null    int64
#  25  approve                105 non-null    int64
#  26  subwayline             45 non-null     object
#  27  stationname            45 non-null     object
#  28  linestaion             45 non-null     object
#  29  latitude               105 non-null    float64
#  30  longitude              105 non-null    float64
#  31  hitags                 2 non-null      object
#  32  resumeProcessRate      105 non-null    int64
#  33  resumeProcessDay       105 non-null    int64
#  34  score                  105 non-null    int64
#  35  newScore               105 non-null    int64
#  36  matchScore             105 non-null    float64
#  37  matchScoreExplain      0 non-null      float64
#  38  query                  0 non-null      float64
#  39  explain                0 non-null      float64
#  40  isSchoolJob            105 non-null    int64
#  41  adWord                 105 non-null    int64
#  42  plus                   0 non-null      float64
#  43  pcShow                 105 non-null    int64
#  44  appShow                105 non-null    int64
#  45  deliver                105 non-null    int64
#  46  gradeDescription       0 non-null      float64
#  47  promotionScoreExplain  0 non-null      float64
#  48  isHotHire              105 non-null    int64
#  49  count                  105 non-null    int64
#  50  aggregatePositionIds   105 non-null    object
#  51  famousCompany          105 non-null    bool
# dtypes: bool(1), float64(9), int64(14), object(28)
# memory usage: 42.1+ KB

# %% [markdown]
# ### 15 读取 Excel 文件｜指定格式（时间）
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并将 `createTime` 列设置为日期格式

# %%
data = pd.read_csv('./某招聘网站数据.csv'
    ,parse_dates=['createTime'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   positionId             105 non-null    int64
#  1   positionName           105 non-null    object
#  2   companyId              105 non-null    int64
#  3   companySize            105 non-null    object
#  4   industryField          105 non-null    object
#  5   financeStage           105 non-null    object
#  6   companyLabelList       105 non-null    object
#  7   firstType              105 non-null    object
#  8   secondType             105 non-null    object
#  9   thirdType              105 non-null    object
#  10  skillLables            105 non-null    object
#  11  positionLables         105 non-null    object
#  12  industryLables         105 non-null    object
#  13  createTime             105 non-null    datetime64[ns]
#  14  formatCreateTime       105 non-null    object
#  15  district               105 non-null    object
#  16  businessZones          53 non-null     object
#  17  salary                 105 non-null    int64
#  18  workYear               105 non-null    object
#  19  jobNature              105 non-null    object
#  20  education              105 non-null    object
#  21  positionAdvantage      105 non-null    object
#  22  imState                105 non-null    object
#  23  lastLogin              105 non-null    object
#  24  publisherId            105 non-null    int64
#  25  approve                105 non-null    int64
#  26  subwayline             45 non-null     object
#  27  stationname            45 non-null     object
#  28  linestaion             45 non-null     object
#  29  latitude               105 non-null    float64
#  30  longitude              105 non-null    float64
#  31  hitags                 2 non-null      object
#  32  resumeProcessRate      105 non-null    int64
#  33  resumeProcessDay       105 non-null    int64
#  34  score                  105 non-null    int64
#  35  newScore               105 non-null    int64
#  36  matchScore             105 non-null    float64
#  37  matchScoreExplain      0 non-null      float64
#  38  query                  0 non-null      float64
#  39  explain                0 non-null      float64
#  40  isSchoolJob            105 non-null    int64
#  41  adWord                 105 non-null    int64
#  42  plus                   0 non-null      float64
#  43  pcShow                 105 non-null    int64
#  44  appShow                105 non-null    int64
#  45  deliver                105 non-null    int64
#  46  gradeDescription       0 non-null      float64
#  47  promotionScoreExplain  0 non-null      float64
#  48  isHotHire              105 non-null    int64
#  49  count                  105 non-null    int64
#  50  aggregatePositionIds   105 non-null    object
#  51  famousCompany          105 non-null    bool
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(16), object(25)
# memory usage: 42.1+ KB

# %% [markdown]
# ### 16 读取 Excel 文件｜分块读取
#
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，要求返回一个可迭代对象，每次读取 10 行
#
# 思考：为什么这样做？

# %%
data = pd.read_csv('./某招聘网站数据.csv'
    ,chunksize=10)

# %% [markdown]
# ### 17 读取 txt 文件｜常规
#
# <br>
#
# 读取当前目录下 `Titanic.txt` 文件。
#
# 注意：在接下来的几种格式文件读取中，对于之前重复的参数/功能将不再整理，仅介绍读取功能。

# %%
data = pd.read_table('./Titanic.txt')
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### 18 读取 txt 文件｜含中文
#
# <br>
#
# 读取当前目录下 `TOP250.txt` 文件。

# %%
data = pd.read_table('./TOP250.txt',encoding='gb18030')
data.head()
# Out:
#         片名  上映年份   评分     评价人数        导演                编剧  \
# 0   肖申克的救赎  1994  9.7  2317937  弗兰克·德拉邦特  弗兰克·德拉邦特 / 斯蒂芬·金
# 1     霸王别姬  1993  9.6  1720638       陈凯歌          芦苇 / 李碧华
# 2     阿甘正传  1994  9.5  1743966  罗伯特·泽米吉斯  艾瑞克·罗斯 / 温斯顿·格鲁姆
# 3  这个杀手不太冷  1994  9.4  1922740     吕克·贝松             吕克·贝松
# 4    泰坦尼克号  1997  9.4  1706127   詹姆斯·卡梅隆           詹姆斯·卡梅隆
#
#                                                   主演            类型 国家/地区  \
# 0  蒂姆·罗宾斯 / 摩根·弗里曼 / 鲍勃·冈顿 / 威廉姆·赛德勒 / 克兰西·布朗 / 吉...       剧情 / 犯罪    美国
# 1  张国荣 / 张丰毅 / 巩俐 / 葛优 / 英达 / 蒋雯丽 / 吴大维 / 吕齐 / 雷汉...  剧情 / 爱情 / 同性    中国
# 2  汤姆·汉克斯 / 罗宾·怀特 / 加里·西尼斯 / 麦凯尔泰·威廉逊 / 莎莉·菲尔德 / ...       剧情 / 爱情    美国
# 3  让·雷诺 / 娜塔莉·波特曼 / 加里·奥德曼 / 丹尼·爱罗 / 彼得·阿佩尔 / 迈克尔...  剧情 / 动作 / 犯罪    法国
# 4  莱昂纳多·迪卡普里奥 / 凯特·温丝莱特 / 比利·赞恩 / 凯西·贝茨 / 弗兰西丝·费舍...  剧情 / 爱情 / 灾难    美国
#
#       语言  时长(分钟)
# 0     英语     142
# 1  汉语普通话     171
# 2     英语     142
# 3    英语      110
# 4    英语      194

# %% [markdown]
# ### 19 读取 JSON 文件
#
#
#
# <br>
#
# 读取当前目录下 `某基金数据.json` 文件。

# %%
data = pd.read_json('./某基金数据.json')
data.head()
# Out:
#          净值日期   单位净值   累计净值    日增长率  申购状态  赎回状态  分红送配
# 0  2020-02-13  1.884  1.884  -0.11%  开放申购  开放赎回   NaN
# 1  2020-02-12  1.886  1.886   3.34%  开放申购  开放赎回   NaN
# 2  2020-02-11  1.825  1.825  -0.16%  开放申购  开放赎回   NaN
# 3  2020-02-10  1.828  1.828   1.33%  开放申购  开放赎回   NaN
# 4  2020-02-07  1.804  1.804   0.61%  开放申购  开放赎回   NaN

# %% [markdown]
# ### 20 读取 HDF5 文件
#
# <br>
#
# `HDF5`是一种特殊的文件格式，常见于在大规模存储数据上
#
# 关于 `pandas` 与 `hdf5` 格式文件的操作较多，下面仅学习如何读取。
#
# 读取当前目录下`store_tl.h5`文件

# %%
data = pd.read_hdf('./store_tl.h5','table')
data.head()
# Out:
#    A  B
# 0  0  0
# 1  1  1
# 2  2  2
# 3  3  3
# 4  4  4

# %% [markdown]
# ### 21 从剪贴板读取数据
#
# <br>
#
# 打开当前目录下 `Titanic.txt` 文件，全选并复制。
#
# 现在直接从剪贴板读取数据。

# %%
data = pd.read_clipboard()
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### 22 从 SQL 读取数据
#
# <br>
#
# 有时我们需要从 `SQL` 中读取数据，如果先将数据导出再`pandas`读取并不是一个合适的选择。
#
# 在 `pandas` 中支持直接从 `sql` 中查询并读取。
#
# 为了方便统一操作，请先执行下面的代码创建数据。

# %%
import pymysql
conn = pymysql.connect(host='localhost',user='root',password='1236987450zxw',database='sys')

# %% [markdown]
# 下面将 `SQL` 语句 `SELECT int_column, date_column FROM test_data` 转换为 `DataFrame`

# %%
data = pd.read_sql('Select * From sys_config',conn)
data
# Out:
# C:\Users\86159\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\io\sql.py:761: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#                                variable  value            set_time set_by
# 0          diagnostics.allow_i_s_tables    OFF 2021-11-17 19:28:48   None
# 1               diagnostics.include_raw    OFF 2021-11-17 19:28:48   None
# 2         ps_thread_trx_info.max_length  65535 2021-11-17 19:28:48   None
# 3  statement_performance_analyzer.limit    100 2021-11-17 19:28:48   None
# 4   statement_performance_analyzer.view   None 2021-11-17 19:28:48   None
# 5                statement_truncate_len     64 2021-11-17 19:28:48   None

# %% [markdown]
# ### 23 从网页读取数据
#
# <br>
#
# 直接从东京奥运会官网读取奖牌榜数据。
#
# 目标网站地址为 `https://olympics.com/tokyo-2020/olympic-games/zh/results/all-sports/medal-standings.htm`
#
# 思考：什么类型的在线表格可以直接读取？

# %%
data = pd.read_html('https://xueqiu.com/snowman/S/00700/detail#/GSLRB')
data

# %% [markdown]
# ### 24 循环读取数据
#
# <br>
#
# 在本小节 `demodata` 文件夹下有多个 `Excel` 文件，要求一次性循环读取全部文件

# %%
import os
path = './demodata/'
filenames = os.listdir(path)
filenames = [f for f in filenames if f.lower().endswith('.xlsx')]
df_list = []
for fileanme in filenames:
    df_list.append(pd.read_excel(path + fileanme))

df = pd.concat(df_list)

# %%
df.head()
# Out:
#            日期  日增长率    涨跌  持有金额   剩余本金   操作      总资产
# 0  2020-01-02  2.92    up   0.0  20000  NaN  20000.0
# 1  2020-01-03  0.51    up   0.0  20000  NaN  20000.0
# 2  2020-01-06  1.98    up   0.0  20000  NaN  20000.0
# 3  2020-01-07  0.17    up   0.0  20000  NaN  20000.0
# 4  2020-01-08 -1.16  down   0.0  20000  NaN  20000.0

# %% [markdown]
# ## 1-2 数据创建
#
# <br>
#
# 除了直接读取本地文件，学会直接创建数据框也很重要，常见于测试一些函数，下面是从常见数据结构创建数据框的方法整理

# %% [markdown]
# ### 25 从列表创建
#
# <br>
#
# 将下面的 `list` 转换为 `dataframe`，并指定列名为`"林肯Python"`

# %%
l = [1,2,3,4,5]

# %%
pd.DataFrame(l,columns=['林肯Python'])
# Out:
#    林肯Python
# 0         1
# 1         2
# 2         3
# 3         4
# 4         5

# %% [markdown]
# ### 26 从列表创建｜嵌套列表
#
# <br>
#
# 将下面的 `list` 转换为 `dataframe`，并指定行索引为`"公众号","林肯Python"`

# %%
l = [[1,2,3],[4,5,6]]

# %%
pd.DataFrame(l,index=['公众号','林肯Python'])
# Out:
#           0  1  2
# 公众号       1  2  3
# 林肯Python  4  5  6

# %% [markdown]
# ### 27 从字典创建

# %% [markdown]
# 执行下方代码，并将字典转换为`dataframe`

# %%
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]) }

# %%
pd.DataFrame(d)
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %% [markdown]
# ### 28 从字典创建｜指定索引
#
# <br>
#
# 还是上一题的字典`d`，将其转换为`dataframe`并指定索引顺序为 `d、b、a`

# %%
pd.DataFrame(d,index=['d','b','a'])
# Out:
#    one  two
# d  NaN  4.0
# b  2.0  2.0
# a  1.0  1.0

# %% [markdown]
# ### 29 从字典创建｜指定列名
#
# <br>
#
# 还是上一题的字典`d`，将其转换为`dataframe`并指定索引顺序为 `d、b、a`，列名为`"two", "three"`

# %%
data = pd.DataFrame(d, index=["d", "b", "a"], columns=["two", "three"])
data
# Out:
#    two three
# d  4.0   NaN
# b  2.0   NaN
# a  1.0   NaN

# %% [markdown]
# ### 30 从字典创建｜字典列表
# <br>
#
# 将下方列表型字典转换为`dataframe`
#
# 思考：如何指定行/列索引？

# %%
d = [{"a": 1, "b": 2}, {"a": 5, "b": 10, "c": 20}]

# %%
pd.DataFrame(d)
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %% [markdown]
# ### 31 从集合创建
#
# <br>
#
# 将下面的元组转换为 dataframe 且行列索引均为 `1,2,3,4`

# %%
t =((1,0,0,0,),(2,3,0,0,),(4,5,6,0,),(7,8,9,10,))

# %%
pd.DataFrame(t,index=[1,2,3,4])
# Out:
#    0  1  2   3
# 1  1  0  0   0
# 2  2  3  0   0
# 3  4  5  6   0
# 4  7  8  9  10

# %% [markdown]
# ## 1-3 数据存储

# %% [markdown]
# ### 32 保存为 CSV
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意）

# %%
data = pd.read_csv("某招聘网站数据.csv",nrows = 20)

# %%
data.to_csv('sbl.csv')

# %% [markdown]
# ### 33 保存为 CSV｜指定列
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意），且只保留`positionName、salary`两列

# %%
data.to_csv('sbl.csv',columns=['positionName','salary'])

# %% [markdown]
# ### 34 保存为 CSV｜取消索引
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意），且取消每一行的索引

# %%
data.to_csv('sbl.csv',index=False)

# %% [markdown]
# ### 35 保存为 CSV｜标记缺失值
#
# <br>
#
# 在上一题的基础上，在保存的同时，将缺失值标记为`'数据缺失'`

# %%
data.to_csv('sbl.csv',index=False, na_rep='数据缺失')

# %% [markdown]
# ### 36 保存为CSV｜压缩
#
# <br>
#
# 将上一题的数据保存至 `zip` 文件，解压后出现 `out.csv`

# %%
compression_opts = dict(method = 'zip',archive_nqme = 'out.csv')
data.to_csv('out.zip',index=False,compression=compression_opts)

# %% [markdown]
# ### 37 保存为 Excel
#
# <br>
#
# 将第三题读取到的数据保存为 `xlsx` 格式至当前目录下（文件名任意）

# %%
data.to_excel('sb.xlsx')

# %% [markdown]
# ### 38 保存为 JSON
#
# 将之前的数据保存为 `json` 格式至当前目录下（文件名任意）

# %%
data.to_json('sb.json')

# %% [markdown]
# ### 39 保存为 Markdown

# %% [markdown]
# 将之前数据转换为 `markdown` 形式表格，这样可以直接复制进 `.md` 文件中使用

# %%
data.to_markdown(index=False)

# %% [markdown]
# ### 40 保存为 Html
#
# 将之前的数据保存为 `html` 格式至当前目录下（文件名任意），并进行如下设置
# - 取消行索引
# - 标题居中对齐
# - 列宽100

# %%
data.to_html('sb.html',col_space=100,index=None,justify='center',border=l)
